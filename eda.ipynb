# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv('reduced_version_data_ENEL_645.csv')
data
# Out:
#           Sector       Community Name Group Category  \
# 0      NORTHEAST            WHITEHORN          Crime
# 1           EAST            FOOTHILLS          Crime
# 2          SOUTH               ACADIA          Crime
# 3      SOUTHEAST             MAHOGANY          Crime
# 4           WEST         LINCOLN PARK          Crime
# ...          ...                  ...            ...
# 99995      SOUTH             WOODBINE       Disorder
# 99996       WEST  NORTH GLENMORE PARK          Crime
# 99997      SOUTH             HAYSBORO       Disorder
# 99998      SOUTH  FAIRVIEW INDUSTRIAL       Disorder
# 99999     CENTRE  KILLARNEY/GLENGARRY          Crime
#
#                        Category  Crime Count  Resident Count  Year Month
# 0                Street Robbery            1           12019  2019   SEP
# 1              Theft OF Vehicle           10             317  2019   NOV
# 2            Theft FROM Vehicle           13           10520  2019   SEP
# ...

# %%
fig, ax = plt.subplots(1,3)
cols = ['Resident Count', 'Year', 'Category']
for i in range(len(ax)):
    feature = cols[i]
    ax[i].scatter(data[feature],data["Crime Count"], label=feature)
    ax[i].set_xlabel(feature)
    ax[i].legend()
ax[0].set_ylabel("Crime Count")
plt.show()
